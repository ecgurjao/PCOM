# %% [markdown]
# ## Multiplicaçao de Variáveis Aleatórias e FDP conjunta
#
#
#
# ### Exemplo
#
# Considerando as Funções Densidade de Probabilidade (FDP) equiprováveis ($P(n = 0) = 1/2$ e $P(n = 1,5A) = 1/2$) e a FDP de uma vairável equiprovavável $P(x) = 1/2A,\ x \in [-A, A]$, temos que
#
# ![Convolucoes_FDPs](./Figuras/convolucao_FDPs.jpg)
